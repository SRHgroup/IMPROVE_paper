# %%
import os
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import datetime

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import roc_auc_score, roc_curve, auc
from sklearn.preprocessing import StandardScaler
from sklearn.utils import shuffle
from sklearn.neural_network import MLPClassifier

# %%
# costumized stuff  
traindir = '../../data/03_partitioning_data/train/'
testdir = '../../data/03_partitioning_data/test/'
valdir = '../../data/03_partitioning_data/validation/'
patient_data = True
only_imp_cols = False

# %%
# run the data with or without the patient data for tumor microenviroment and with or withput selected cols
#print("running model with only_imp_cols:" + only_imp_cols + "and patient_data"+ patient_data)
print(patient_data)
print(only_imp_cols)

if patient_data == True and only_imp_cols == False: 
    cols_to_drop = ['response','Peptide', 'HLA_allele','Patient','partitoning','cohort','est_freq']
    TME_inc = "TME_included"
if patient_data == False and only_imp_cols == False: 
    cols_to_drop = ['response','Peptide', 'HLA_allele','Patient','partitoning','cohort','est_freq',"CYT","CD8A"]
    TME_inc = "TME_excluded"
    print(TME_inc)
if patient_data == True and only_imp_cols == True: 
    cols_to_drop = ['response','Peptide', 'HLA_allele','Patient','partitoning','cohort','est_freq',"Expression_Level","Mut_MHCrank_EL"]
    TME_inc = "TME_included"
if patient_data == False and only_imp_cols == True: 
    cols_to_drop = ['response','Peptide', 'HLA_allele','Patient','partitoning','cohort','est_freq',"CYT","CD8A","Expression_Level","Mut_MHCrank_EL","cellular_prevalence","variant_allele_frequency"]
    TME_inc = "TME_excluded"

    #
    

#my_auc=list()
n_sample = 10

pred_val_rf = []
pred_val_mlp = []

model_out_dir = "../../models/" +TME_inc + '_' +datetime.datetime.now().strftime('%Y-%m-%d_%H-%M-%S')
#os.makedirs("/home/xxx/" + datetime.datetime.now().strftime('%Y-%m-%d_%H-%M-%S'))
os.makedirs(model_out_dir)

Var_importance_filename = '../../results/RandomForrest/tabels/Feature_importance_' + TME_inc +'.txt'
outfile = open(Var_importance_filename ,'w')
# Out:
# True
# False

# %%
pred_df = pd.DataFrame()
for file in os.listdir(traindir):
    print("Partition:", file)
    filename = file[5:7]
    train = pd.read_csv(traindir + "/"+ file, sep='\t')
    train = train.dropna()
    train['response'].value_counts()

    # test set 
    av_pred_rf = 0
    av_pred_mlp = 0
    
    test = pd.read_csv(testdir + '/test' + filename + '.txt', sep='\t')
    test = test.dropna()
    test['response'].value_counts()
    print(len(test))
    # Because of downsampling is needed, make the downsampling 10 times (or 3 if you just debug :) ) 
    for i in range(n_sample): 
        train_pos = train[train.response==1]
        train_neg = train[train.response==0].sample(n=1000, random_state=i) #, random_state=45
        train = shuffle(pd.concat([train_pos, train_neg], axis=0)).reset_index(drop=True)
        X_train = train.drop(cols_to_drop, axis=1).reset_index(drop=True)
        y_train = train["response"]
        
        feature_list = list(X_train.columns)
        
        # Instantiate the RF and the MLP
        rf = RandomForestClassifier(n_estimators = 1000, random_state = 42, max_depth = 3)
        mlp = MLPClassifier(max_iter=500, hidden_layer_sizes=200)
    
        # Train the models on training data
        rf.fit(X_train, y_train)
        mlp.fit(X_train, y_train)
        filename = model_out_dir +"/rf_"+file+"_"+"sample"+str(i)+".sav"
        pickle.dump(rf,open(filename,"wb"))
     #   pickle.dump(mlp,open("../../models/Version1/mlp_"+file+"sample"+str(i)),"wb")
        
        #Get fetures importance per partition
        importances = list(rf.feature_importances_)
        feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
        # Sort
        feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
        [print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances]
        # gather all feature importance 
        for pair in feature_importances:
            outfile.write(str(pair[0]) + "\t" + str(pair[1]) + "\n")
            
     

        # Test set 
        test.columns = train.columns 
        X_test = test.drop(cols_to_drop, axis=1).reset_index(drop=True)
        y_test = test["response"]  
        test_cols = X_test.columns
    
        predictions_rf = rf.predict_proba(X_test)
        predictions_mlp = mlp.predict_proba(X_test)
        
        av_pred_rf += predictions_rf
        av_pred_mlp += predictions_mlp
    
    pred_val_rf = av_pred_rf/n_sample
    pred_val_mlp = av_pred_mlp/n_sample
    
    pred_df = pred_df.append(pd.concat([pd.DataFrame(X_test, columns=X_test.columns), 
    pd.Series(y_test, name='response'), 
    pd.Series(pred_val_rf[:,1], name='prediction_rf'),                          
    pd.Series(pred_val_mlp[:,1], name='prediction_mlp')], axis=1)).reset_index(drop=True)

pred_df=pred_df.dropna()
print(pred_df)
# Print final AUCs 
print("RF AUC:",round(roc_auc_score(pred_df.response, pred_df.prediction_rf),4))
print("MLP AUC:",round(roc_auc_score(pred_df.response, pred_df.prediction_mlp),4))
    
            
        
outfile.close()
# Out:
# Partition: train03.txt
# 6764
# Variable: HLA_expression       Importance: 0.09
# Variable: CD8A                 Importance: 0.09
# Variable: CYT                  Importance: 0.09
# Variable: MeanHydroph_coreNoAnc Importance: 0.07
# Variable: hydro                Importance: 0.07
# Variable: X.Rank_PRIME         Importance: 0.06
# Variable: Score_PRIME          Importance: 0.06
# Variable: HydroPhobRatio       Importance: 0.05
# Variable: helix                Importance: 0.04
# Variable: Mut_MHCrank_EL       Importance: 0.04
# Variable: Mut_MHCrank_BA       Importance: 0.03
# Variable: Prop_Hydrophobic     Importance: 0.03
# Variable: inst                 Importance: 0.02
# Variable: variant_allele_frequency Importance: 0.02
# Variable: cellular_prevalence  Importance: 0.02
# Variable: mw                   Importance: 0.01
# Variable: aro                  Importance: 0.01
# Variable: turn                 Importance: 0.01
# Variable: sheet                Importance: 0.01
# Variable: Allele_Frequency     Importance: 0.01
# Variable: Expression_Level     Importance: 0.01
# Variable: priority_Score       Importance: 0.01
# Variable: Self_Similarity      Importance: 0.01
# Variable: Thalf.h.             Importance: 0.01
# Variable: MeanHelix            Importance: 0.01
# Variable: MeanHelix_coreNoAnc  Importance: 0.01
# Variable: Prop_Aliphatic       Importance: 0.01
# Variable: Prop_Aromatic        Importance: 0.01
# Variable: Prop_Non.polar       Importance: 0.01
# Variable: Prop_Polar           Importance: 0.01
# Variable: clonal_mut           Importance: 0.01
# Variable: pI                   Importance: 0.01
# Variable: agretopicity         Importance: 0.01
# Variable: DAI                  Importance: 0.01
# Variable: exp_rank_binary      Importance: 0.01
# Variable: mut_rep_rank_netstabpan Importance: 0.01
# Variable: cys_red              Importance: 0.0
# Variable: Cancer_Driver_Gene   Importance: 0.0
# Variable: Of                   Importance: 0.0
# Variable: Gp                   Importance: 0.0
# Variable: Il                   Importance: 0.0
# Variable: Prop_Tiny            Importance: 0.0
# Variable: Prop_Small           Importance: 0.0
# Variable: Prop_Charged         Importance: 0.0
# Variable: Prop_Basic           Importance: 0.0
# Variable: Prop_Acidic          Importance: 0.0
# Variable: Misense_mutation     Importance: 0.0
# Variable: Frameshift_mutation  Importance: 0.0
# Variable: Inframe_deletion_mutation Importance: 0.0
# Variable: Inframe_insertion    Importance: 0.0
# Variable: foginess_score       Importance: 0.0
# Variable: CYT                  Importance: 0.1
# Variable: HLA_expression       Importance: 0.09
# Variable: CD8A                 Importance: 0.09
# Variable: hydro                Importance: 0.07
# Variable: X.Rank_PRIME         Importance: 0.06
# Variable: Score_PRIME          Importance: 0.06
# Variable: MeanHydroph_coreNoAnc Importance: 0.06
# Variable: HydroPhobRatio       Importance: 0.05
# Variable: helix                Importance: 0.04
# Variable: Mut_MHCrank_EL       Importance: 0.04
# Variable: Mut_MHCrank_BA       Importance: 0.03
# Variable: Prop_Hydrophobic     Importance: 0.03
# Variable: inst                 Importance: 0.02
# Variable: variant_allele_frequency Importance: 0.02
# Variable: cellular_prevalence  Importance: 0.02
# Variable: agretopicity         Importance: 0.02
# Variable: exp_rank_binary      Importance: 0.02
# Variable: mw                   Importance: 0.01
# Variable: aro                  Importance: 0.01
# Variable: turn                 Importance: 0.01
# Variable: sheet                Importance: 0.01
# Variable: Allele_Frequency     Importance: 0.01
# Variable: Expression_Level     Importance: 0.01
# Variable: priority_Score       Importance: 0.01
# Variable: Self_Similarity      Importance: 0.01
# Variable: Thalf.h.             Importance: 0.01
# Variable: MeanHelix            Importance: 0.01
# Variable: MeanHelix_coreNoAnc  Importance: 0.01
# Variable: Prop_Aliphatic       Importance: 0.01
# Variable: Prop_Non.polar       Importance: 0.01
# Variable: Prop_Polar           Importance: 0.01
# Variable: clonal_mut           Importance: 0.01
# Variable: pI                   Importance: 0.01
# Variable: DAI                  Importance: 0.01
# Variable: mut_rep_rank_netstabpan Importance: 0.01
# Variable: cys_red              Importance: 0.0
# Variable: Cancer_Driver_Gene   Importance: 0.0
# Variable: Of                   Importance: 0.0
# Variable: Gp                   Importance: 0.0
# Variable: Il                   Importance: 0.0
# Variable: Prop_Tiny            Importance: 0.0
# Variable: Prop_Small           Importance: 0.0
# Variable: Prop_Aromatic        Importance: 0.0
# Variable: Prop_Charged         Importance: 0.0
# Variable: Prop_Basic           Importance: 0.0
# Variable: Prop_Acidic          Importance: 0.0
# Variable: Misense_mutation     Importance: 0.0
# Variable: Frameshift_mutation  Importance: 0.0
# Variable: Inframe_deletion_mutation Importance: 0.0
# Variable: Inframe_insertion    Importance: 0.0
# Variable: foginess_score       Importance: 0.0
# Variable: HLA_expression       Importance: 0.09
# Variable: CD8A                 Importance: 0.09
# Variable: CYT                  Importance: 0.09
# Variable: MeanHydroph_coreNoAnc Importance: 0.07
# Variable: hydro                Importance: 0.07
# Variable: Score_PRIME          Importance: 0.06
# Variable: X.Rank_PRIME         Importance: 0.05
# Variable: helix                Importance: 0.04
# Variable: Mut_MHCrank_EL       Importance: 0.04
# Variable: HydroPhobRatio       Importance: 0.04
# Variable: Mut_MHCrank_BA       Importance: 0.03
# Variable: Prop_Hydrophobic     Importance: 0.03
# Variable: inst                 Importance: 0.02
# Variable: cellular_prevalence  Importance: 0.02
# Variable: pI                   Importance: 0.02
# Variable: agretopicity         Importance: 0.02
# Variable: exp_rank_binary      Importance: 0.02
# Variable: mw                   Importance: 0.01
# Variable: aro                  Importance: 0.01
# Variable: turn                 Importance: 0.01
# Variable: sheet                Importance: 0.01
# Variable: Allele_Frequency     Importance: 0.01
# Variable: Expression_Level     Importance: 0.01
# Variable: priority_Score       Importance: 0.01
# Variable: variant_allele_frequency Importance: 0.01
# Variable: Self_Similarity      Importance: 0.01
# Variable: Thalf.h.             Importance: 0.01
# Variable: MeanHelix            Importance: 0.01
# Variable: MeanHelix_coreNoAnc  Importance: 0.01
# Variable: Prop_Aliphatic       Importance: 0.01
# Variable: Prop_Aromatic        Importance: 0.01
# Variable: Prop_Non.polar       Importance: 0.01
# Variable: Prop_Polar           Importance: 0.01
# Variable: clonal_mut           Importance: 0.01
# Variable: DAI                  Importance: 0.01
# Variable: mut_rep_rank_netstabpan Importance: 0.01
# Variable: cys_red              Importance: 0.0
# Variable: Cancer_Driver_Gene   Importance: 0.0
# Variable: Of                   Importance: 0.0
# Variable: Gp                   Importance: 0.0
# Variable: Il                   Importance: 0.0
# Variable: Prop_Tiny            Importance: 0.0
# Variable: Prop_Small           Importance: 0.0
# Variable: Prop_Charged         Importance: 0.0
# Variable: Prop_Basic           Importance: 0.0
# Variable: Prop_Acidic          Importance: 0.0
# Variable: Misense_mutation     Importance: 0.0
# Variable: Frameshift_mutation  Importance: 0.0
# Variable: Inframe_deletion_mutation Importance: 0.0
# Variable: Inframe_insertion    Importance: 0.0
# Variable: foginess_score       Importance: 0.0
# Variable: HLA_expression       Importance: 0.09
# Variable: CD8A                 Importance: 0.09
# Variable: CYT                  Importance: 0.09
# Variable: MeanHydroph_coreNoAnc Importance: 0.07
# Variable: hydro                Importance: 0.07
# Variable: X.Rank_PRIME         Importance: 0.06
# Variable: Score_PRIME          Importance: 0.06
# Variable: HydroPhobRatio       Importance: 0.05
# Variable: helix                Importance: 0.04
# Variable: Mut_MHCrank_EL       Importance: 0.03
# Variable: Mut_MHCrank_BA       Importance: 0.03
# Variable: Prop_Hydrophobic     Importance: 0.03
# Variable: inst                 Importance: 0.02
# Variable: variant_allele_frequency Importance: 0.02
# Variable: cellular_prevalence  Importance: 0.02
# Variable: pI                   Importance: 0.02
# Variable: agretopicity         Importance: 0.02
# Variable: exp_rank_binary      Importance: 0.02
# Variable: mw                   Importance: 0.01
# Variable: aro                  Importance: 0.01
# Variable: turn                 Importance: 0.01
# Variable: sheet                Importance: 0.01
# Variable: Allele_Frequency     Importance: 0.01
# Variable: Expression_Level     Importance: 0.01
# Variable: priority_Score       Importance: 0.01
# Variable: Self_Similarity      Importance: 0.01
# Variable: Thalf.h.             Importance: 0.01
# Variable: MeanHelix            Importance: 0.01
# Variable: MeanHelix_coreNoAnc  Importance: 0.01
# Variable: Prop_Aliphatic       Importance: 0.01
# Variable: Prop_Aromatic        Importance: 0.01
# Variable: Prop_Non.polar       Importance: 0.01
# Variable: Prop_Polar           Importance: 0.01
# Variable: clonal_mut           Importance: 0.01
# Variable: DAI                  Importance: 0.01
# Variable: mut_rep_rank_netstabpan Importance: 0.01
# Variable: cys_red              Importance: 0.0
# Variable: Cancer_Driver_Gene   Importance: 0.0
# Variable: Of                   Importance: 0.0
# Variable: Gp                   Importance: 0.0
# Variable: Il                   Importance: 0.0
# Variable: Prop_Tiny            Importance: 0.0
# Variable: Prop_Small           Importance: 0.0
# Variable: Prop_Charged         Importance: 0.0
# Variable: Prop_Basic           Importance: 0.0
# Variable: Prop_Acidic          Importance: 0.0
# Variable: Misense_mutation     Importance: 0.0
# Variable: Frameshift_mutation  Importance: 0.0
# Variable: Inframe_deletion_mutation Importance: 0.0
# Variable: Inframe_insertion    Importance: 0.0
# Variable: foginess_score       Importance: 0.0
# Variable: CYT                  Importance: 0.1
# Variable: HLA_expression       Importance: 0.09
# Variable: CD8A                 Importance: 0.09
# Variable: MeanHydroph_coreNoAnc Importance: 0.07
# Variable: Score_PRIME          Importance: 0.06
# Variable: hydro                Importance: 0.06
# Variable: X.Rank_PRIME         Importance: 0.05
# Variable: HydroPhobRatio       Importance: 0.05
# Variable: helix                Importance: 0.04
# Variable: Mut_MHCrank_EL       Importance: 0.04
# Variable: Mut_MHCrank_BA       Importance: 0.03
# Variable: Prop_Hydrophobic     Importance: 0.03
# Variable: inst                 Importance: 0.02
# Variable: variant_allele_frequency Importance: 0.02
# Variable: cellular_prevalence  Importance: 0.02
# Variable: agretopicity         Importance: 0.02
# Variable: mw                   Importance: 0.01
# Variable: aro                  Importance: 0.01
# Variable: turn                 Importance: 0.01
# Variable: sheet                Importance: 0.01
# Variable: Allele_Frequency     Importance: 0.01
# Variable: Expression_Level     Importance: 0.01
# Variable: priority_Score       Importance: 0.01
# Variable: Self_Similarity      Importance: 0.01
# Variable: Thalf.h.             Importance: 0.01
# Variable: MeanHelix            Importance: 0.01
# Variable: MeanHelix_coreNoAnc  Importance: 0.01
# Variable: Prop_Aliphatic       Importance: 0.01
# Variable: Prop_Aromatic        Importance: 0.01
# Variable: Prop_Non.polar       Importance: 0.01
# Variable: Prop_Polar           Importance: 0.01
# Variable: clonal_mut           Importance: 0.01
# Variable: pI                   Importance: 0.01
# Variable: DAI                  Importance: 0.01
# Variable: exp_rank_binary      Importance: 0.01
# Variable: mut_rep_rank_netstabpan Importance: 0.01
# Variable: cys_red              Importance: 0.0
# Variable: Cancer_Driver_Gene   Importance: 0.0
# Variable: Of                   Importance: 0.0
# Variable: Gp                   Importance: 0.0
# Variable: Il                   Importance: 0.0
# Variable: Prop_Tiny            Importance: 0.0
# Variable: Prop_Small           Importance: 0.0
# Variable: Prop_Charged         Importance: 0.0
# Variable: Prop_Basic           Importance: 0.0
# Variable: Prop_Acidic          Importance: 0.0
# Variable: Misense_mutation     Importance: 0.0
# Variable: Frameshift_mutation  Importance: 0.0
# Variable: Inframe_deletion_mutation Importance: 0.0
# Variable: Inframe_insertion    Importance: 0.0
# Variable: foginess_score       Importance: 0.0
# Variable: HLA_expression       Importance: 0.09
# Variable: CD8A                 Importance: 0.09
# Variable: CYT                  Importance: 0.09
# Variable: MeanHydroph_coreNoAnc Importance: 0.07
# Variable: hydro                Importance: 0.07
# Variable: Score_PRIME          Importance: 0.06
# Variable: X.Rank_PRIME         Importance: 0.05
# Variable: HydroPhobRatio       Importance: 0.05
# Variable: helix                Importance: 0.04
# Variable: Mut_MHCrank_EL       Importance: 0.04
# Variable: Mut_MHCrank_BA       Importance: 0.03
# Variable: Prop_Hydrophobic     Importance: 0.03
# Variable: inst                 Importance: 0.02
# Variable: cellular_prevalence  Importance: 0.02
# Variable: agretopicity         Importance: 0.02
# Variable: mw                   Importance: 0.01
# Variable: aro                  Importance: 0.01
# Variable: turn                 Importance: 0.01
# Variable: sheet                Importance: 0.01
# Variable: Allele_Frequency     Importance: 0.01
# Variable: Expression_Level     Importance: 0.01
# Variable: priority_Score       Importance: 0.01
# Variable: variant_allele_frequency Importance: 0.01
# Variable: Self_Similarity      Importance: 0.01
# Variable: Thalf.h.             Importance: 0.01
# Variable: MeanHelix            Importance: 0.01
# Variable: MeanHelix_coreNoAnc  Importance: 0.01
# Variable: Prop_Aliphatic       Importance: 0.01
# Variable: Prop_Aromatic        Importance: 0.01
# Variable: Prop_Non.polar       Importance: 0.01
# Variable: Prop_Polar           Importance: 0.01
# Variable: clonal_mut           Importance: 0.01
# Variable: pI                   Importance: 0.01
# Variable: DAI                  Importance: 0.01
# Variable: exp_rank_binary      Importance: 0.01
# Variable: mut_rep_rank_netstabpan Importance: 0.01
# Variable: cys_red              Importance: 0.0
# Variable: Cancer_Driver_Gene   Importance: 0.0
# Variable: Of                   Importance: 0.0
# Variable: Gp                   Importance: 0.0
# Variable: Il                   Importance: 0.0
# Variable: Prop_Tiny            Importance: 0.0
# Variable: Prop_Small           Importance: 0.0
# Variable: Prop_Charged         Importance: 0.0
# Variable: Prop_Basic           Importance: 0.0
# Variable: Prop_Acidic          Importance: 0.0
# Variable: Misense_mutation     Importance: 0.0
# Variable: Frameshift_mutation  Importance: 0.0
# Variable: Inframe_deletion_mutation Importance: 0.0
# Variable: Inframe_insertion    Importance: 0.0
# Variable: foginess_score       Importance: 0.0
# Variable: CYT                  Importance: 0.1
# Variable: HLA_expression       Importance: 0.09
# Variable: CD8A                 Importance: 0.09
# Variable: MeanHydroph_coreNoAnc Importance: 0.07
# Variable: hydro                Importance: 0.07
# Variable: Score_PRIME          Importance: 0.06
# Variable: X.Rank_PRIME         Importance: 0.05
# Variable: HydroPhobRatio       Importance: 0.05
# Variable: helix                Importance: 0.04
# Variable: Mut_MHCrank_EL       Importance: 0.04
# Variable: Mut_MHCrank_BA       Importance: 0.03
# Variable: Prop_Hydrophobic     Importance: 0.03
# Variable: inst                 Importance: 0.02
# Variable: cellular_prevalence  Importance: 0.02
# Variable: exp_rank_binary      Importance: 0.02
# Variable: mw                   Importance: 0.01
# Variable: aro                  Importance: 0.01
# Variable: sheet                Importance: 0.01
# Variable: Allele_Frequency     Importance: 0.01
# Variable: Expression_Level     Importance: 0.01
# Variable: priority_Score       Importance: 0.01
# Variable: variant_allele_frequency Importance: 0.01
# Variable: Self_Similarity      Importance: 0.01
# Variable: Thalf.h.             Importance: 0.01
# Variable: MeanHelix            Importance: 0.01
# Variable: MeanHelix_coreNoAnc  Importance: 0.01
# Variable: Prop_Aliphatic       Importance: 0.01
# Variable: Prop_Aromatic        Importance: 0.01
# Variable: Prop_Non.polar       Importance: 0.01
# Variable: Prop_Polar           Importance: 0.01
# Variable: clonal_mut           Importance: 0.01
# Variable: pI                   Importance: 0.01
# Variable: agretopicity         Importance: 0.01
# Variable: DAI                  Importance: 0.01
# Variable: mut_rep_rank_netstabpan Importance: 0.01
# Variable: turn                 Importance: 0.0
# Variable: cys_red              Importance: 0.0
# Variable: Cancer_Driver_Gene   Importance: 0.0
# Variable: Of                   Importance: 0.0
# Variable: Gp                   Importance: 0.0
# Variable: Il                   Importance: 0.0
# Variable: Prop_Tiny            Importance: 0.0
# Variable: Prop_Small           Importance: 0.0
# Variable: Prop_Charged         Importance: 0.0
# Variable: Prop_Basic           Importance: 0.0
# Variable: Prop_Acidic          Importance: 0.0
# Variable: Misense_mutation     Importance: 0.0
# Variable: Frameshift_mutation  Importance: 0.0
# Variable: Inframe_deletion_mutation Importance: 0.0
# Variable: Inframe_insertion    Importance: 0.0
# Variable: foginess_score       Importance: 0.0
# Variable: CYT                  Importance: 0.1
# Variable: HLA_expression       Importance: 0.09
# Variable: CD8A                 Importance: 0.09
# Variable: MeanHydroph_coreNoAnc Importance: 0.07
# Variable: hydro                Importance: 0.07
# Variable: X.Rank_PRIME         Importance: 0.06
# Variable: Score_PRIME          Importance: 0.06
# Variable: HydroPhobRatio       Importance: 0.05
# Variable: helix                Importance: 0.04
# Variable: Mut_MHCrank_EL       Importance: 0.04
# Variable: Mut_MHCrank_BA       Importance: 0.03
# Variable: Prop_Hydrophobic     Importance: 0.03
# Variable: inst                 Importance: 0.02
# Variable: variant_allele_frequency Importance: 0.02
# Variable: cellular_prevalence  Importance: 0.02
# Variable: agretopicity         Importance: 0.02
# Variable: mw                   Importance: 0.01
# Variable: aro                  Importance: 0.01
# Variable: turn                 Importance: 0.01
# Variable: sheet                Importance: 0.01
# Variable: Allele_Frequency     Importance: 0.01
# Variable: Expression_Level     Importance: 0.01
# Variable: priority_Score       Importance: 0.01
# Variable: Self_Similarity      Importance: 0.01
# Variable: Thalf.h.             Importance: 0.01
# Variable: MeanHelix            Importance: 0.01
# Variable: Prop_Aliphatic       Importance: 0.01
# Variable: Prop_Aromatic        Importance: 0.01
# Variable: Prop_Non.polar       Importance: 0.01
# Variable: Prop_Polar           Importance: 0.01
# Variable: clonal_mut           Importance: 0.01
# Variable: pI                   Importance: 0.01
# Variable: DAI                  Importance: 0.01
# Variable: exp_rank_binary      Importance: 0.01
# Variable: mut_rep_rank_netstabpan Importance: 0.01
# Variable: cys_red              Importance: 0.0
# Variable: Cancer_Driver_Gene   Importance: 0.0
# Variable: Of                   Importance: 0.0
# Variable: Gp                   Importance: 0.0
# Variable: Il                   Importance: 0.0
# Variable: MeanHelix_coreNoAnc  Importance: 0.0
# Variable: Prop_Tiny            Importance: 0.0
# Variable: Prop_Small           Importance: 0.0
# Variable: Prop_Charged         Importance: 0.0
# Variable: Prop_Basic           Importance: 0.0
# Variable: Prop_Acidic          Importance: 0.0
# Variable: Misense_mutation     Importance: 0.0
# Variable: Frameshift_mutation  Importance: 0.0
# Variable: Inframe_deletion_mutation Importance: 0.0
# Variable: Inframe_insertion    Importance: 0.0
# Variable: foginess_score       Importance: 0.0
# Variable: CYT                  Importance: 0.1
# Variable: HLA_expression       Importance: 0.09
# Variable: CD8A                 Importance: 0.09
# Variable: MeanHydroph_coreNoAnc Importance: 0.07
# Variable: X.Rank_PRIME         Importance: 0.06
# Variable: Score_PRIME          Importance: 0.06
# Variable: hydro                Importance: 0.06
# Variable: HydroPhobRatio       Importance: 0.05
# Variable: helix                Importance: 0.04
# Variable: Mut_MHCrank_EL       Importance: 0.04
# Variable: Mut_MHCrank_BA       Importance: 0.03
# Variable: Prop_Hydrophobic     Importance: 0.03
# Variable: inst                 Importance: 0.02
# Variable: variant_allele_frequency Importance: 0.02
# Variable: cellular_prevalence  Importance: 0.02
# Variable: pI                   Importance: 0.02
# Variable: exp_rank_binary      Importance: 0.02
# Variable: mw                   Importance: 0.01
# Variable: aro                  Importance: 0.01
# Variable: turn                 Importance: 0.01
# Variable: Allele_Frequency     Importance: 0.01
# Variable: Expression_Level     Importance: 0.01
# Variable: priority_Score       Importance: 0.01
# Variable: Self_Similarity      Importance: 0.01
# Variable: Thalf.h.             Importance: 0.01
# Variable: MeanHelix            Importance: 0.01
# Variable: MeanHelix_coreNoAnc  Importance: 0.01
# Variable: Prop_Aliphatic       Importance: 0.01
# Variable: Prop_Aromatic        Importance: 0.01
# Variable: Prop_Non.polar       Importance: 0.01
# Variable: Prop_Polar           Importance: 0.01
# Variable: clonal_mut           Importance: 0.01
# Variable: agretopicity         Importance: 0.01
# Variable: DAI                  Importance: 0.01
# Variable: mut_rep_rank_netstabpan Importance: 0.01
# Variable: sheet                Importance: 0.0
# Variable: cys_red              Importance: 0.0
# Variable: Cancer_Driver_Gene   Importance: 0.0
# Variable: Of                   Importance: 0.0
# Variable: Gp                   Importance: 0.0
# Variable: Il                   Importance: 0.0
# Variable: Prop_Tiny            Importance: 0.0
# Variable: Prop_Small           Importance: 0.0
# Variable: Prop_Charged         Importance: 0.0
# Variable: Prop_Basic           Importance: 0.0
# Variable: Prop_Acidic          Importance: 0.0
# Variable: Misense_mutation     Importance: 0.0
# Variable: Frameshift_mutation  Importance: 0.0
# Variable: Inframe_deletion_mutation Importance: 0.0
# Variable: Inframe_insertion    Importance: 0.0
# Variable: foginess_score       Importance: 0.0
# Variable: HLA_expression       Importance: 0.09
# Variable: CD8A                 Importance: 0.09
# Variable: CYT                  Importance: 0.09
# Variable: MeanHydroph_coreNoAnc Importance: 0.07
# Variable: X.Rank_PRIME         Importance: 0.06
# Variable: Score_PRIME          Importance: 0.06
# Variable: hydro                Importance: 0.06
# Variable: HydroPhobRatio       Importance: 0.05
# Variable: helix                Importance: 0.04
# Variable: Mut_MHCrank_EL       Importance: 0.04
# Variable: Mut_MHCrank_BA       Importance: 0.03
# Variable: Prop_Hydrophobic     Importance: 0.03
# Variable: inst                 Importance: 0.02
# Variable: variant_allele_frequency Importance: 0.02
# Variable: cellular_prevalence  Importance: 0.02
# Variable: pI                   Importance: 0.02
# Variable: agretopicity         Importance: 0.02
# Variable: exp_rank_binary      Importance: 0.02
# Variable: mw                   Importance: 0.01
# Variable: aro                  Importance: 0.01
# Variable: turn                 Importance: 0.01
# Variable: sheet                Importance: 0.01
# Variable: Allele_Frequency     Importance: 0.01
# Variable: Expression_Level     Importance: 0.01
# Variable: priority_Score       Importance: 0.01
# Variable: Self_Similarity      Importance: 0.01
# Variable: Thalf.h.             Importance: 0.01
# Variable: MeanHelix            Importance: 0.01
# Variable: MeanHelix_coreNoAnc  Importance: 0.01
# Variable: Prop_Aliphatic       Importance: 0.01
# Variable: Prop_Aromatic        Importance: 0.01
# Variable: Prop_Non.polar       Importance: 0.01
# Variable: Prop_Polar           Importance: 0.01
# Variable: clonal_mut           Importance: 0.01
# Variable: DAI                  Importance: 0.01
# Variable: mut_rep_rank_netstabpan Importance: 0.01
# Variable: cys_red              Importance: 0.0
# Variable: Cancer_Driver_Gene   Importance: 0.0
# Variable: Of                   Importance: 0.0
# Variable: Gp                   Importance: 0.0
# Variable: Il                   Importance: 0.0
# Variable: Prop_Tiny            Importance: 0.0
# Variable: Prop_Small           Importance: 0.0
# Variable: Prop_Charged         Importance: 0.0
# Variable: Prop_Basic           Importance: 0.0
# Variable: Prop_Acidic          Importance: 0.0
# Variable: Misense_mutation     Importance: 0.0
# Variable: Frameshift_mutation  Importance: 0.0
# Variable: Inframe_deletion_mutation Importance: 0.0
# Variable: Inframe_insertion    Importance: 0.0
# Variable: foginess_score       Importance: 0.0
# Partition: train02.txt
# 3628
# Variable: MeanHydroph_coreNoAnc Importance: 0.1
# Variable: hydro                Importance: 0.09
# Variable: helix                Importance: 0.07
# Variable: Prop_Hydrophobic     Importance: 0.07
# Variable: HydroPhobRatio       Importance: 0.06
# Variable: Score_PRIME          Importance: 0.04
# Variable: HLA_expression       Importance: 0.04
# Variable: CYT                  Importance: 0.04
# Variable: Mut_MHCrank_BA       Importance: 0.03
# Variable: X.Rank_PRIME         Importance: 0.03
# Variable: DAI                  Importance: 0.03
# Variable: CD8A                 Importance: 0.03
# Variable: mw                   Importance: 0.02
# Variable: inst                 Importance: 0.02
# Variable: Mut_MHCrank_EL       Importance: 0.02
# Variable: Allele_Frequency     Importance: 0.02
# Variable: Self_Similarity      Importance: 0.02
# Variable: Prop_Aliphatic       Importance: 0.02
# Variable: Prop_Aromatic        Importance: 0.02
# Variable: Prop_Non.polar       Importance: 0.02
# Variable: Prop_Polar           Importance: 0.02
# Variable: agretopicity         Importance: 0.02
# Variable: aro                  Importance: 0.01
# Variable: turn                 Importance: 0.01
# Variable: sheet                Importance: 0.01
# Variable: cys_red              Importance: 0.01
# Variable: Expression_Level     Importance: 0.01
# Variable: priority_Score       Importance: 0.01
# Variable: variant_allele_frequency Importance: 0.01
# Variable: cellular_prevalence  Importance: 0.01
# Variable: Thalf.h.             Importance: 0.01
# Variable: MeanHelix            Importance: 0.01
# Variable: MeanHelix_coreNoAnc  Importance: 0.01
# Variable: Prop_Tiny            Importance: 0.01
# Variable: Prop_Small           Importance: 0.01
# Variable: Prop_Charged         Importance: 0.01
# Variable: pI                   Importance: 0.01
# Variable: mut_rep_rank_netstabpan Importance: 0.01
# Variable: Cancer_Driver_Gene   Importance: 0.0
# Variable: Of                   Importance: 0.0
# Variable: Gp                   Importance: 0.0
# Variable: Il                   Importance: 0.0
# Variable: Prop_Basic           Importance: 0.0
# Variable: Prop_Acidic          Importance: 0.0
# Variable: Misense_mutation     Importance: 0.0
# Variable: Frameshift_mutation  Importance: 0.0
# Variable: Inframe_deletion_mutation Importance: 0.0
# Variable: Inframe_insertion    Importance: 0.0
# Variable: clonal_mut           Importance: 0.0
# Variable: exp_rank_binary      Importance: 0.0
# Variable: foginess_score       Importance: 0.0
# Variable: MeanHydroph_coreNoAnc Importance: 0.1
# Variable: hydro                Importance: 0.09
# Variable: Prop_Hydrophobic     Importance: 0.07
# Variable: helix                Importance: 0.06
# Variable: HydroPhobRatio       Importance: 0.06
# Variable: Score_PRIME          Importance: 0.04
# Variable: HLA_expression       Importance: 0.04
# Variable: CD8A                 Importance: 0.04
# Variable: CYT                  Importance: 0.04
# Variable: Mut_MHCrank_BA       Importance: 0.03
# Variable: X.Rank_PRIME         Importance: 0.03
# Variable: DAI                  Importance: 0.03
# Variable: mw                   Importance: 0.02
# Variable: inst                 Importance: 0.02
# Variable: Mut_MHCrank_EL       Importance: 0.02
# Variable: Allele_Frequency     Importance: 0.02
# Variable: Self_Similarity      Importance: 0.02
# Variable: MeanHelix_coreNoAnc  Importance: 0.02
# Variable: Prop_Aromatic        Importance: 0.02
# Variable: Prop_Non.polar       Importance: 0.02
# Variable: Prop_Polar           Importance: 0.02
# Variable: pI                   Importance: 0.02
# Variable: agretopicity         Importance: 0.02
# Variable: aro                  Importance: 0.01
# Variable: turn                 Importance: 0.01
# Variable: sheet                Importance: 0.01
# Variable: cys_red              Importance: 0.01
# Variable: Expression_Level     Importance: 0.01
# Variable: priority_Score       Importance: 0.01
# Variable: variant_allele_frequency Importance: 0.01
# Variable: cellular_prevalence  Importance: 0.01
# Variable: Thalf.h.             Importance: 0.01
# Variable: MeanHelix            Importance: 0.01
# Variable: Prop_Tiny            Importance: 0.01
# Variable: Prop_Small           Importance: 0.01
# Variable: Prop_Aliphatic       Importance: 0.01
# Variable: Prop_Charged         Importance: 0.01
# Variable: mut_rep_rank_netstabpan Importance: 0.01
# Variable: Cancer_Driver_Gene   Importance: 0.0
# Variable: Of                   Importance: 0.0
# Variable: Gp                   Importance: 0.0
# Variable: Il                   Importance: 0.0
# Variable: Prop_Basic           Importance: 0.0
# Variable: Prop_Acidic          Importance: 0.0
# Variable: Misense_mutation     Importance: 0.0
# Variable: Frameshift_mutation  Importance: 0.0
# Variable: Inframe_deletion_mutation Importance: 0.0
# Variable: Inframe_insertion    Importance: 0.0
# Variable: clonal_mut           Importance: 0.0
# Variable: exp_rank_binary      Importance: 0.0
# Variable: foginess_score       Importance: 0.0
# Variable: MeanHydroph_coreNoAnc Importance: 0.1
# Variable: hydro                Importance: 0.1
# Variable: helix                Importance: 0.07
# Variable: Prop_Hydrophobic     Importance: 0.07
# Variable: HydroPhobRatio       Importance: 0.06
# Variable: HLA_expression       Importance: 0.05
# Variable: Score_PRIME          Importance: 0.04
# Variable: CD8A                 Importance: 0.04
# Variable: CYT                  Importance: 0.04
# Variable: Mut_MHCrank_BA       Importance: 0.03
# Variable: DAI                  Importance: 0.03
# Variable: mw                   Importance: 0.02
# Variable: Mut_MHCrank_EL       Importance: 0.02
# Variable: Allele_Frequency     Importance: 0.02
# Variable: Self_Similarity      Importance: 0.02
# Variable: X.Rank_PRIME         Importance: 0.02
# Variable: MeanHelix_coreNoAnc  Importance: 0.02
# Variable: Prop_Aromatic        Importance: 0.02
# Variable: Prop_Non.polar       Importance: 0.02
# Variable: Prop_Polar           Importance: 0.02
# Variable: pI                   Importance: 0.02
# Variable: agretopicity         Importance: 0.02
# Variable: aro                  Importance: 0.01
# Variable: inst                 Importance: 0.01
# Variable: turn                 Importance: 0.01
# Variable: sheet                Importance: 0.01
# Variable: cys_red              Importance: 0.01
# Variable: Expression_Level     Importance: 0.01
# Variable: priority_Score       Importance: 0.01
# Variable: variant_allele_frequency Importance: 0.01
# Variable: cellular_prevalence  Importance: 0.01
# Variable: Thalf.h.             Importance: 0.01
# Variable: MeanHelix            Importance: 0.01
# Variable: Prop_Tiny            Importance: 0.01
# Variable: Prop_Small           Importance: 0.01
# Variable: Prop_Aliphatic       Importance: 0.01
# Variable: Prop_Charged         Importance: 0.01
# Variable: Cancer_Driver_Gene   Importance: 0.0
# Variable: Of                   Importance: 0.0
# Variable: Gp                   Importance: 0.0
# Variable: Il                   Importance: 0.0
# Variable: Prop_Basic           Importance: 0.0
# Variable: Prop_Acidic          Importance: 0.0
# Variable: Misense_mutation     Importance: 0.0
# Variable: Frameshift_mutation  Importance: 0.0
# Variable: Inframe_deletion_mutation Importance: 0.0
# Variable: Inframe_insertion    Importance: 0.0
# Variable: clonal_mut           Importance: 0.0
# Variable: exp_rank_binary      Importance: 0.0
# Variable: mut_rep_rank_netstabpan Importance: 0.0
# Variable: foginess_score       Importance: 0.0
# Variable: MeanHydroph_coreNoAnc Importance: 0.1
# Variable: hydro                Importance: 0.1
# Variable: helix                Importance: 0.07
# Variable: HydroPhobRatio       Importance: 0.07
# Variable: Prop_Hydrophobic     Importance: 0.07
# Variable: Score_PRIME          Importance: 0.04
# Variable: DAI                  Importance: 0.04
# Variable: HLA_expression       Importance: 0.04
# Variable: CD8A                 Importance: 0.04
# Variable: CYT                  Importance: 0.04
# Variable: Mut_MHCrank_BA       Importance: 0.03
# Variable: X.Rank_PRIME         Importance: 0.03
# Variable: mw                   Importance: 0.02
# Variable: Mut_MHCrank_EL       Importance: 0.02
# Variable: Allele_Frequency     Importance: 0.02
# Variable: Self_Similarity      Importance: 0.02
# Variable: MeanHelix_coreNoAnc  Importance: 0.02
# Variable: Prop_Aliphatic       Importance: 0.02
# Variable: Prop_Aromatic        Importance: 0.02
# Variable: Prop_Non.polar       Importance: 0.02
# Variable: Prop_Polar           Importance: 0.02
# Variable: pI                   Importance: 0.02
# Variable: agretopicity         Importance: 0.02
# Variable: aro                  Importance: 0.01
# Variable: inst                 Importance: 0.01
# Variable: turn                 Importance: 0.01
# Variable: sheet                Importance: 0.01
# Variable: cys_red              Importance: 0.01
# Variable: Expression_Level     Importance: 0.01
# Variable: priority_Score       Importance: 0.01
# Variable: variant_allele_frequency Importance: 0.01
# Variable: cellular_prevalence  Importance: 0.01
# Variable: Thalf.h.             Importance: 0.01
# Variable: MeanHelix            Importance: 0.01
# Variable: Prop_Tiny            Importance: 0.01
# Variable: Prop_Small           Importance: 0.01
# Variable: Prop_Charged         Importance: 0.01
# Variable: mut_rep_rank_netstabpan Importance: 0.01
# Variable: Cancer_Driver_Gene   Importance: 0.0
# Variable: Of                   Importance: 0.0
# Variable: Gp                   Importance: 0.0
# Variable: Il                   Importance: 0.0
# Variable: Prop_Basic           Importance: 0.0
# Variable: Prop_Acidic          Importance: 0.0
# Variable: Misense_mutation     Importance: 0.0
# Variable: Frameshift_mutation  Importance: 0.0
# Variable: Inframe_deletion_mutation Importance: 0.0
# Variable: Inframe_insertion    Importance: 0.0
# Variable: clonal_mut           Importance: 0.0
# Variable: exp_rank_binary      Importance: 0.0
# Variable: foginess_score       Importance: 0.0
# Variable: MeanHydroph_coreNoAnc Importance: 0.1
# Variable: hydro                Importance: 0.09
# Variable: HydroPhobRatio       Importance: 0.07
# Variable: Prop_Hydrophobic     Importance: 0.07
# Variable: helix                Importance: 0.06
# Variable: Score_PRIME          Importance: 0.04
# Variable: HLA_expression       Importance: 0.04
# Variable: CD8A                 Importance: 0.04
# Variable: CYT                  Importance: 0.04
# Variable: Mut_MHCrank_BA       Importance: 0.03
# Variable: DAI                  Importance: 0.03
# Variable: mw                   Importance: 0.02
# Variable: Mut_MHCrank_EL       Importance: 0.02
# Variable: Allele_Frequency     Importance: 0.02
# Variable: Self_Similarity      Importance: 0.02
# Variable: X.Rank_PRIME         Importance: 0.02
# Variable: MeanHelix            Importance: 0.02
# Variable: Prop_Aliphatic       Importance: 0.02
# Variable: Prop_Non.polar       Importance: 0.02
# Variable: Prop_Polar           Importance: 0.02
# Variable: agretopicity         Importance: 0.02
# Variable: aro                  Importance: 0.01
# Variable: inst                 Importance: 0.01
# Variable: turn                 Importance: 0.01
# Variable: sheet                Importance: 0.01
# Variable: cys_red              Importance: 0.01
# Variable: Expression_Level     Importance: 0.01
# Variable: priority_Score       Importance: 0.01
# Variable: variant_allele_frequency Importance: 0.01
# Variable: cellular_prevalence  Importance: 0.01
# Variable: Thalf.h.             Importance: 0.01
# Variable: MeanHelix_coreNoAnc  Importance: 0.01
# Variable: Prop_Tiny            Importance: 0.01
# Variable: Prop_Small           Importance: 0.01
# Variable: Prop_Aromatic        Importance: 0.01
# Variable: Prop_Charged         Importance: 0.01
# Variable: pI                   Importance: 0.01
# Variable: mut_rep_rank_netstabpan Importance: 0.01
# Variable: Cancer_Driver_Gene   Importance: 0.0
# Variable: Of                   Importance: 0.0
# Variable: Gp                   Importance: 0.0
# Variable: Il                   Importance: 0.0
# Variable: Prop_Basic           Importance: 0.0
# Variable: Prop_Acidic          Importance: 0.0
# Variable: Misense_mutation     Importance: 0.0
# Variable: Frameshift_mutation  Importance: 0.0
# Variable: Inframe_deletion_mutation Importance: 0.0
# Variable: Inframe_insertion    Importance: 0.0
# Variable: clonal_mut           Importance: 0.0
# Variable: exp_rank_binary      Importance: 0.0
# Variable: foginess_score       Importance: 0.0
# Variable: MeanHydroph_coreNoAnc Importance: 0.1
# Variable: hydro                Importance: 0.09
# Variable: helix                Importance: 0.07
# Variable: Prop_Hydrophobic     Importance: 0.07
# Variable: HydroPhobRatio       Importance: 0.06
# Variable: Score_PRIME          Importance: 0.04
# Variable: HLA_expression       Importance: 0.04
# Variable: CD8A                 Importance: 0.04
# Variable: CYT                  Importance: 0.04
# Variable: Mut_MHCrank_BA       Importance: 0.03
# Variable: X.Rank_PRIME         Importance: 0.03
# Variable: DAI                  Importance: 0.03
# Variable: mw                   Importance: 0.02
# Variable: Mut_MHCrank_EL       Importance: 0.02
# Variable: Allele_Frequency     Importance: 0.02
# Variable: Self_Similarity      Importance: 0.02
# Variable: Prop_Aliphatic       Importance: 0.02
# Variable: Prop_Aromatic        Importance: 0.02
# Variable: Prop_Non.polar       Importance: 0.02
# Variable: Prop_Polar           Importance: 0.02
# Variable: pI                   Importance: 0.02
# Variable: agretopicity         Importance: 0.02
# Variable: aro                  Importance: 0.01
# Variable: inst                 Importance: 0.01
# Variable: turn                 Importance: 0.01
# Variable: sheet                Importance: 0.01
# Variable: cys_red              Importance: 0.01
# Variable: Expression_Level     Importance: 0.01
# Variable: priority_Score       Importance: 0.01
# Variable: variant_allele_frequency Importance: 0.01
# Variable: cellular_prevalence  Importance: 0.01
# Variable: Thalf.h.             Importance: 0.01
# Variable: MeanHelix            Importance: 0.01
# Variable: MeanHelix_coreNoAnc  Importance: 0.01
# Variable: Prop_Tiny            Importance: 0.01
# Variable: Prop_Small           Importance: 0.01
# Variable: Prop_Charged         Importance: 0.01
# Variable: Cancer_Driver_Gene   Importance: 0.0
# Variable: Of                   Importance: 0.0
# Variable: Gp                   Importance: 0.0
# Variable: Il                   Importance: 0.0
# Variable: Prop_Basic           Importance: 0.0
# Variable: Prop_Acidic          Importance: 0.0
# Variable: Misense_mutation     Importance: 0.0
# Variable: Frameshift_mutation  Importance: 0.0
# Variable: Inframe_deletion_mutation Importance: 0.0
# Variable: Inframe_insertion    Importance: 0.0
# Variable: clonal_mut           Importance: 0.0
# Variable: exp_rank_binary      Importance: 0.0
# Variable: mut_rep_rank_netstabpan Importance: 0.0
# Variable: foginess_score       Importance: 0.0
# Variable: MeanHydroph_coreNoAnc Importance: 0.1
# Variable: hydro                Importance: 0.09
# Variable: Prop_Hydrophobic     Importance: 0.08
# Variable: HydroPhobRatio       Importance: 0.07
# Variable: helix                Importance: 0.06
# Variable: Score_PRIME          Importance: 0.04
# Variable: HLA_expression       Importance: 0.04
# Variable: CD8A                 Importance: 0.04
# Variable: CYT                  Importance: 0.04
# Variable: Mut_MHCrank_BA       Importance: 0.03
# Variable: DAI                  Importance: 0.03
# Variable: mw                   Importance: 0.02
# Variable: Mut_MHCrank_EL       Importance: 0.02
# Variable: Allele_Frequency     Importance: 0.02
# Variable: Self_Similarity      Importance: 0.02
# Variable: X.Rank_PRIME         Importance: 0.02
# Variable: MeanHelix_coreNoAnc  Importance: 0.02
# Variable: Prop_Aliphatic       Importance: 0.02
# Variable: Prop_Aromatic        Importance: 0.02
# Variable: Prop_Non.polar       Importance: 0.02
# Variable: Prop_Polar           Importance: 0.02
# Variable: agretopicity         Importance: 0.02
# Variable: aro                  Importance: 0.01
# Variable: inst                 Importance: 0.01
# Variable: turn                 Importance: 0.01
# Variable: sheet                Importance: 0.01
# Variable: cys_red              Importance: 0.01
# Variable: Expression_Level     Importance: 0.01
# Variable: priority_Score       Importance: 0.01
# Variable: variant_allele_frequency Importance: 0.01
# Variable: cellular_prevalence  Importance: 0.01
# Variable: Thalf.h.             Importance: 0.01
# Variable: MeanHelix            Importance: 0.01
# Variable: Prop_Tiny            Importance: 0.01
# Variable: Prop_Small           Importance: 0.01
# Variable: Prop_Charged         Importance: 0.01
# Variable: pI                   Importance: 0.01
# Variable: exp_rank_binary      Importance: 0.01
# Variable: mut_rep_rank_netstabpan Importance: 0.01
# Variable: Cancer_Driver_Gene   Importance: 0.0
# Variable: Of                   Importance: 0.0
# Variable: Gp                   Importance: 0.0
# Variable: Il                   Importance: 0.0
# Variable: Prop_Basic           Importance: 0.0
# Variable: Prop_Acidic          Importance: 0.0
# Variable: Misense_mutation     Importance: 0.0
# Variable: Frameshift_mutation  Importance: 0.0
# Variable: Inframe_deletion_mutation Importance: 0.0
# Variable: Inframe_insertion    Importance: 0.0
# Variable: clonal_mut           Importance: 0.0
# Variable: foginess_score       Importance: 0.0
# Variable: MeanHydroph_coreNoAnc Importance: 0.1
# Variable: hydro                Importance: 0.1
# Variable: Prop_Hydrophobic     Importance: 0.07
# Variable: helix                Importance: 0.06
# Variable: HydroPhobRatio       Importance: 0.06
# Variable: Score_PRIME          Importance: 0.04
# Variable: HLA_expression       Importance: 0.04
# Variable: CD8A                 Importance: 0.04
# Variable: CYT                  Importance: 0.04
# Variable: Mut_MHCrank_BA       Importance: 0.03
# Variable: DAI                  Importance: 0.03
# Variable: mw                   Importance: 0.02
# Variable: inst                 Importance: 0.02
# Variable: Mut_MHCrank_EL       Importance: 0.02
# Variable: Allele_Frequency     Importance: 0.02
# Variable: Self_Similarity      Importance: 0.02
# Variable: X.Rank_PRIME         Importance: 0.02
# Variable: Prop_Aliphatic       Importance: 0.02
# Variable: Prop_Aromatic        Importance: 0.02
# Variable: Prop_Non.polar       Importance: 0.02
# Variable: Prop_Polar           Importance: 0.02
# Variable: pI                   Importance: 0.02
# Variable: agretopicity         Importance: 0.02
# Variable: aro                  Importance: 0.01
# Variable: turn                 Importance: 0.01
# Variable: sheet                Importance: 0.01
# Variable: cys_red              Importance: 0.01
# Variable: Expression_Level     Importance: 0.01
# Variable: priority_Score       Importance: 0.01
# Variable: variant_allele_frequency Importance: 0.01
# Variable: cellular_prevalence  Importance: 0.01
# Variable: Thalf.h.             Importance: 0.01
# Variable: MeanHelix            Importance: 0.01
# Variable: MeanHelix_coreNoAnc  Importance: 0.01
# Variable: Prop_Tiny            Importance: 0.01
# Variable: Prop_Small           Importance: 0.01
# Variable: Prop_Charged         Importance: 0.01
# Variable: mut_rep_rank_netstabpan Importance: 0.01
# Variable: Cancer_Driver_Gene   Importance: 0.0
# Variable: Of                   Importance: 0.0
# Variable: Gp                   Importance: 0.0
# Variable: Il                   Importance: 0.0
# Variable: Prop_Basic           Importance: 0.0
# Variable: Prop_Acidic          Importance: 0.0
# Variable: Misense_mutation     Importance: 0.0
# Variable: Frameshift_mutation  Importance: 0.0
# Variable: Inframe_deletion_mutation Importance: 0.0
# Variable: Inframe_insertion    Importance: 0.0
# Variable: clonal_mut           Importance: 0.0
# Variable: exp_rank_binary      Importance: 0.0
# Variable: foginess_score       Importance: 0.0
# Variable: hydro                Importance: 0.1
# Variable: MeanHydroph_coreNoAnc Importance: 0.09
# Variable: Prop_Hydrophobic     Importance: 0.07
# Variable: helix                Importance: 0.06
# Variable: HydroPhobRatio       Importance: 0.06
# Variable: Score_PRIME          Importance: 0.04
# Variable: HLA_expression       Importance: 0.04
# Variable: CD8A                 Importance: 0.04
# Variable: CYT                  Importance: 0.04
# Variable: Mut_MHCrank_BA       Importance: 0.03
# Variable: X.Rank_PRIME         Importance: 0.03
# Variable: DAI                  Importance: 0.03
# Variable: mw                   Importance: 0.02
# Variable: Mut_MHCrank_EL       Importance: 0.02
# Variable: Allele_Frequency     Importance: 0.02
# Variable: Self_Similarity      Importance: 0.02
# Variable: MeanHelix_coreNoAnc  Importance: 0.02
# Variable: Prop_Aliphatic       Importance: 0.02
# Variable: Prop_Aromatic        Importance: 0.02
# Variable: Prop_Non.polar       Importance: 0.02
# Variable: Prop_Polar           Importance: 0.02
# Variable: pI                   Importance: 0.02
# Variable: agretopicity         Importance: 0.02
# Variable: aro                  Importance: 0.01
# Variable: inst                 Importance: 0.01
# Variable: turn                 Importance: 0.01
# Variable: sheet                Importance: 0.01
# Variable: cys_red              Importance: 0.01
# Variable: Expression_Level     Importance: 0.01
# Variable: priority_Score       Importance: 0.01
# Variable: variant_allele_frequency Importance: 0.01
# Variable: cellular_prevalence  Importance: 0.01
# Variable: Thalf.h.             Importance: 0.01
# Variable: MeanHelix            Importance: 0.01
# Variable: Prop_Tiny            Importance: 0.01
# Variable: Prop_Small           Importance: 0.01
# Variable: Prop_Charged         Importance: 0.01
# Variable: exp_rank_binary      Importance: 0.01
# Variable: Cancer_Driver_Gene   Importance: 0.0
# Variable: Of                   Importance: 0.0
# Variable: Gp                   Importance: 0.0
# Variable: Il                   Importance: 0.0
# Variable: Prop_Basic           Importance: 0.0
# Variable: Prop_Acidic          Importance: 0.0
# Variable: Misense_mutation     Importance: 0.0
# Variable: Frameshift_mutation  Importance: 0.0
# Variable: Inframe_deletion_mutation Importance: 0.0
# Variable: Inframe_insertion    Importance: 0.0
# Variable: clonal_mut           Importance: 0.0
# Variable: mut_rep_rank_netstabpan Importance: 0.0
# Variable: foginess_score       Importance: 0.0
# Variable: MeanHydroph_coreNoAnc Importance: 0.1
# Variable: hydro                Importance: 0.1
# Variable: HydroPhobRatio       Importance: 0.07
# Variable: helix                Importance: 0.06
# Variable: Prop_Hydrophobic     Importance: 0.06
# Variable: Score_PRIME          Importance: 0.04
# Variable: DAI                  Importance: 0.04
# Variable: HLA_expression       Importance: 0.04
# Variable: CYT                  Importance: 0.04
# Variable: Mut_MHCrank_BA       Importance: 0.03
# Variable: Allele_Frequency     Importance: 0.03
# Variable: X.Rank_PRIME         Importance: 0.03
# Variable: CD8A                 Importance: 0.03
# Variable: mw                   Importance: 0.02
# Variable: Mut_MHCrank_EL       Importance: 0.02
# Variable: Self_Similarity      Importance: 0.02
# Variable: Prop_Aliphatic       Importance: 0.02
# Variable: Prop_Non.polar       Importance: 0.02
# Variable: Prop_Polar           Importance: 0.02
# Variable: pI                   Importance: 0.02
# Variable: agretopicity         Importance: 0.02
# Variable: aro                  Importance: 0.01
# Variable: inst                 Importance: 0.01
# Variable: turn                 Importance: 0.01
# Variable: sheet                Importance: 0.01
# Variable: cys_red              Importance: 0.01
# Variable: Expression_Level     Importance: 0.01
# Variable: priority_Score       Importance: 0.01
# Variable: variant_allele_frequency Importance: 0.01
# Variable: cellular_prevalence  Importance: 0.01
# ...
# Variable: hydro                Importance: 0.06
# Variable: Mut_MHCrank_EL       Importance: 0.05
# Variable: Score_PRIME          Importance: 0.05
# Variable: HydroPhobRatio       Importance: 0.05
# Variable: CD8A                 Importance: 0.05
# Variable: helix                Importance: 0.04
# Variable: Prop_Hydrophobic     Importance: 0.04
# Variable: HLA_expression       Importance: 0.04
# Variable: Mut_MHCrank_BA       Importance: 0.03
# Variable: X.Rank_PRIME         Importance: 0.03
# Variable: Prop_Non.polar       Importance: 0.03
# Variable: Prop_Polar           Importance: 0.03
# Variable: CYT                  Importance: 0.03
# Variable: inst                 Importance: 0.02
# Variable: variant_allele_frequency Importance: 0.02
# Variable: cellular_prevalence  Importance: 0.02
# Variable: Self_Similarity      Importance: 0.02
# Variable: Prop_Aromatic        Importance: 0.02
# Variable: pI                   Importance: 0.02
# Variable: agretopicity         Importance: 0.02
# Variable: DAI                  Importance: 0.02
# Variable: exp_rank_binary      Importance: 0.02
# Variable: mw                   Importance: 0.01
# Variable: turn                 Importance: 0.01
# Variable: sheet                Importance: 0.01
# Variable: cys_red              Importance: 0.01
# Variable: Allele_Frequency     Importance: 0.01
# Variable: Expression_Level     Importance: 0.01
# Variable: priority_Score       Importance: 0.01
# Variable: Thalf.h.             Importance: 0.01
# Variable: MeanHelix            Importance: 0.01
# Variable: MeanHelix_coreNoAnc  Importance: 0.01
# Variable: Prop_Small           Importance: 0.01
# Variable: Prop_Aliphatic       Importance: 0.01
# Variable: Prop_Charged         Importance: 0.01
# Variable: Inframe_insertion    Importance: 0.01
# Variable: mut_rep_rank_netstabpan Importance: 0.01
# Variable: Cancer_Driver_Gene   Importance: 0.0
# Variable: Of                   Importance: 0.0
# Variable: Gp                   Importance: 0.0
# Variable: Il                   Importance: 0.0
# Variable: Prop_Tiny            Importance: 0.0
# Variable: Prop_Basic           Importance: 0.0
# Variable: Prop_Acidic          Importance: 0.0
# Variable: Misense_mutation     Importance: 0.0
# Variable: Frameshift_mutation  Importance: 0.0
# Variable: Inframe_deletion_mutation Importance: 0.0
# Variable: clonal_mut           Importance: 0.0
# Variable: foginess_score       Importance: 0.0
# Variable: MeanHydroph_coreNoAnc Importance: 0.11
# Variable: aro                  Importance: 0.06
# Variable: helix                Importance: 0.05
# Variable: Mut_MHCrank_EL       Importance: 0.05
# Variable: Score_PRIME          Importance: 0.05
# Variable: HydroPhobRatio       Importance: 0.05
# Variable: hydro                Importance: 0.05
# Variable: CD8A                 Importance: 0.05
# Variable: Prop_Hydrophobic     Importance: 0.04
# Variable: HLA_expression       Importance: 0.04
# Variable: Mut_MHCrank_BA       Importance: 0.03
# Variable: X.Rank_PRIME         Importance: 0.03
# Variable: Prop_Non.polar       Importance: 0.03
# Variable: Prop_Polar           Importance: 0.03
# Variable: CYT                  Importance: 0.03
# Variable: inst                 Importance: 0.02
# Variable: cellular_prevalence  Importance: 0.02
# Variable: Prop_Aromatic        Importance: 0.02
# Variable: pI                   Importance: 0.02
# Variable: DAI                  Importance: 0.02
# Variable: mw                   Importance: 0.01
# Variable: turn                 Importance: 0.01
# Variable: sheet                Importance: 0.01
# Variable: cys_red              Importance: 0.01
# Variable: Allele_Frequency     Importance: 0.01
# Variable: Expression_Level     Importance: 0.01
# Variable: priority_Score       Importance: 0.01
# Variable: variant_allele_frequency Importance: 0.01
# Variable: Self_Similarity      Importance: 0.01
# Variable: Thalf.h.             Importance: 0.01
# Variable: MeanHelix            Importance: 0.01
# Variable: MeanHelix_coreNoAnc  Importance: 0.01
# Variable: Prop_Tiny            Importance: 0.01
# Variable: Prop_Small           Importance: 0.01
# Variable: Prop_Aliphatic       Importance: 0.01
# Variable: Prop_Charged         Importance: 0.01
# Variable: Inframe_insertion    Importance: 0.01
# Variable: agretopicity         Importance: 0.01
# Variable: exp_rank_binary      Importance: 0.01
# Variable: mut_rep_rank_netstabpan Importance: 0.01
# Variable: Cancer_Driver_Gene   Importance: 0.0
# Variable: Of                   Importance: 0.0
# Variable: Gp                   Importance: 0.0
# Variable: Il                   Importance: 0.0
# Variable: Prop_Basic           Importance: 0.0
# Variable: Prop_Acidic          Importance: 0.0
# Variable: Misense_mutation     Importance: 0.0
# Variable: Frameshift_mutation  Importance: 0.0
# Variable: Inframe_deletion_mutation Importance: 0.0
# Variable: clonal_mut           Importance: 0.0
# Variable: foginess_score       Importance: 0.0
# Variable: MeanHydroph_coreNoAnc Importance: 0.1
# Variable: aro                  Importance: 0.06
# Variable: hydro                Importance: 0.06
# Variable: helix                Importance: 0.05
# Variable: Mut_MHCrank_EL       Importance: 0.05
# Variable: Score_PRIME          Importance: 0.05
# Variable: HydroPhobRatio       Importance: 0.05
# Variable: CD8A                 Importance: 0.05
# Variable: Prop_Hydrophobic     Importance: 0.04
# Variable: HLA_expression       Importance: 0.04
# Variable: Mut_MHCrank_BA       Importance: 0.03
# Variable: X.Rank_PRIME         Importance: 0.03
# Variable: Prop_Non.polar       Importance: 0.03
# Variable: Prop_Polar           Importance: 0.03
# Variable: pI                   Importance: 0.03
# Variable: CYT                  Importance: 0.03
# Variable: inst                 Importance: 0.02
# Variable: cellular_prevalence  Importance: 0.02
# Variable: Self_Similarity      Importance: 0.02
# Variable: Prop_Aromatic        Importance: 0.02
# Variable: agretopicity         Importance: 0.02
# Variable: DAI                  Importance: 0.02
# Variable: mw                   Importance: 0.01
# Variable: turn                 Importance: 0.01
# Variable: sheet                Importance: 0.01
# Variable: cys_red              Importance: 0.01
# Variable: Allele_Frequency     Importance: 0.01
# Variable: Expression_Level     Importance: 0.01
# Variable: priority_Score       Importance: 0.01
# Variable: variant_allele_frequency Importance: 0.01
# Variable: Thalf.h.             Importance: 0.01
# Variable: MeanHelix            Importance: 0.01
# Variable: MeanHelix_coreNoAnc  Importance: 0.01
# Variable: Prop_Small           Importance: 0.01
# Variable: Prop_Aliphatic       Importance: 0.01
# Variable: Inframe_insertion    Importance: 0.01
# Variable: exp_rank_binary      Importance: 0.01
# Variable: mut_rep_rank_netstabpan Importance: 0.01
# Variable: Cancer_Driver_Gene   Importance: 0.0
# Variable: Of                   Importance: 0.0
# Variable: Gp                   Importance: 0.0
# Variable: Il                   Importance: 0.0
# Variable: Prop_Tiny            Importance: 0.0
# Variable: Prop_Charged         Importance: 0.0
# Variable: Prop_Basic           Importance: 0.0
# Variable: Prop_Acidic          Importance: 0.0
# Variable: Misense_mutation     Importance: 0.0
# Variable: Frameshift_mutation  Importance: 0.0
# Variable: Inframe_deletion_mutation Importance: 0.0
# Variable: clonal_mut           Importance: 0.0
# Variable: foginess_score       Importance: 0.0
# Variable: MeanHydroph_coreNoAnc Importance: 0.1
# Variable: aro                  Importance: 0.06
# Variable: hydro                Importance: 0.06
# Variable: Mut_MHCrank_EL       Importance: 0.05
# Variable: Score_PRIME          Importance: 0.05
# Variable: HydroPhobRatio       Importance: 0.05
# Variable: CD8A                 Importance: 0.05
# Variable: helix                Importance: 0.04
# Variable: Prop_Hydrophobic     Importance: 0.04
# Variable: Mut_MHCrank_BA       Importance: 0.03
# Variable: X.Rank_PRIME         Importance: 0.03
# Variable: Prop_Non.polar       Importance: 0.03
# Variable: Prop_Polar           Importance: 0.03
# Variable: pI                   Importance: 0.03
# Variable: HLA_expression       Importance: 0.03
# Variable: CYT                  Importance: 0.03
# Variable: inst                 Importance: 0.02
# Variable: variant_allele_frequency Importance: 0.02
# Variable: cellular_prevalence  Importance: 0.02
# Variable: Self_Similarity      Importance: 0.02
# Variable: Prop_Aromatic        Importance: 0.02
# Variable: DAI                  Importance: 0.02
# Variable: mw                   Importance: 0.01
# Variable: turn                 Importance: 0.01
# Variable: sheet                Importance: 0.01
# Variable: cys_red              Importance: 0.01
# Variable: Allele_Frequency     Importance: 0.01
# Variable: Expression_Level     Importance: 0.01
# Variable: priority_Score       Importance: 0.01
# Variable: Thalf.h.             Importance: 0.01
# Variable: MeanHelix            Importance: 0.01
# Variable: MeanHelix_coreNoAnc  Importance: 0.01
# Variable: Prop_Small           Importance: 0.01
# Variable: Prop_Aliphatic       Importance: 0.01
# Variable: Prop_Charged         Importance: 0.01
# Variable: Inframe_insertion    Importance: 0.01
# Variable: agretopicity         Importance: 0.01
# Variable: exp_rank_binary      Importance: 0.01
# Variable: mut_rep_rank_netstabpan Importance: 0.01
# Variable: Cancer_Driver_Gene   Importance: 0.0
# Variable: Of                   Importance: 0.0
# Variable: Gp                   Importance: 0.0
# Variable: Il                   Importance: 0.0
# Variable: Prop_Tiny            Importance: 0.0
# Variable: Prop_Basic           Importance: 0.0
# Variable: Prop_Acidic          Importance: 0.0
# Variable: Misense_mutation     Importance: 0.0
# Variable: Frameshift_mutation  Importance: 0.0
# Variable: Inframe_deletion_mutation Importance: 0.0
# Variable: clonal_mut           Importance: 0.0
# Variable: foginess_score       Importance: 0.0
# Variable: MeanHydroph_coreNoAnc Importance: 0.1
# Variable: aro                  Importance: 0.06
# Variable: hydro                Importance: 0.06
# Variable: Mut_MHCrank_EL       Importance: 0.05
# Variable: Score_PRIME          Importance: 0.05
# Variable: CD8A                 Importance: 0.05
# Variable: helix                Importance: 0.04
# Variable: HydroPhobRatio       Importance: 0.04
# Variable: Prop_Polar           Importance: 0.04
# Variable: Prop_Hydrophobic     Importance: 0.04
# Variable: Mut_MHCrank_BA       Importance: 0.03
# Variable: X.Rank_PRIME         Importance: 0.03
# Variable: Prop_Non.polar       Importance: 0.03
# Variable: HLA_expression       Importance: 0.03
# Variable: CYT                  Importance: 0.03
# Variable: inst                 Importance: 0.02
# Variable: cellular_prevalence  Importance: 0.02
# Variable: Self_Similarity      Importance: 0.02
# Variable: Prop_Aromatic        Importance: 0.02
# Variable: pI                   Importance: 0.02
# Variable: agretopicity         Importance: 0.02
# Variable: DAI                  Importance: 0.02
# Variable: mw                   Importance: 0.01
# Variable: turn                 Importance: 0.01
# Variable: sheet                Importance: 0.01
# Variable: cys_red              Importance: 0.01
# Variable: Allele_Frequency     Importance: 0.01
# Variable: Expression_Level     Importance: 0.01
# Variable: priority_Score       Importance: 0.01
# Variable: variant_allele_frequency Importance: 0.01
# Variable: Thalf.h.             Importance: 0.01
# Variable: MeanHelix            Importance: 0.01
# Variable: MeanHelix_coreNoAnc  Importance: 0.01
# Variable: Prop_Tiny            Importance: 0.01
# Variable: Prop_Small           Importance: 0.01
# Variable: Prop_Aliphatic       Importance: 0.01
# Variable: Prop_Charged         Importance: 0.01
# Variable: Inframe_insertion    Importance: 0.01
# Variable: exp_rank_binary      Importance: 0.01
# Variable: mut_rep_rank_netstabpan Importance: 0.01
# Variable: Cancer_Driver_Gene   Importance: 0.0
# Variable: Of                   Importance: 0.0
# Variable: Gp                   Importance: 0.0
# Variable: Il                   Importance: 0.0
# Variable: Prop_Basic           Importance: 0.0
# Variable: Prop_Acidic          Importance: 0.0
# Variable: Misense_mutation     Importance: 0.0
# Variable: Frameshift_mutation  Importance: 0.0
# Variable: Inframe_deletion_mutation Importance: 0.0
# Variable: clonal_mut           Importance: 0.0
# Variable: foginess_score       Importance: 0.0
#               mw       aro        inst     helix      turn     sheet  cys_red  \
# 0      1170.2745  0.100000   39.030000  0.300000  0.100000  0.400000     1490
# 1      1170.2745  0.100000   39.030000  0.300000  0.100000  0.400000     1490
# 2      1157.2907  0.100000   24.000000  0.400000  0.000000  0.200000     1490
# 3      1044.1331  0.111111   25.555556  0.333333  0.000000  0.111111     1490
# 4       939.2358  0.000000   -0.544444  0.666667  0.111111  0.666667        0
# ...          ...       ...         ...       ...       ...       ...      ...
# 16155  1143.2740  0.000000   -8.960000  0.200000  0.300000  0.200000        0
# 16156  1200.2989  0.000000   41.600000  0.300000  0.100000  0.500000        0
# 16157  1072.1697  0.000000   45.111111  0.333333  0.111111  0.555556        0
# 16158  1072.1697  0.000000   45.111111  0.333333  0.111111  0.555556        0
# 16159  1341.5111  0.181818  128.363636  0.363636  0.090909  0.181818     1490
#
#        Mut_MHCrank_EL  Mut_MHCrank_BA  Allele_Frequency  ...      DAI  \
# 0              0.2137          0.4873             0.063  ...  19.0177
# 1              0.3832          0.7888             0.063  ...  15.2297
# 2              0.0529          0.0194             0.114  ...   0.0012
# 3              0.0059          0.0130             0.114  ...   0.0000
# 4              0.0935          0.2502             0.055  ...  -0.0788
# ...               ...             ...               ...  ...      ...
# 16155          0.7620          1.1224             0.018  ...   0.1978
# 16156          1.2147          3.8764             0.018  ...  12.3599
# 16157          0.1877          1.0638             0.018  ...   2.0491
# 16158          0.2198          0.6685             0.018  ...   4.5807
# 16159          1.4566          0.2730             0.020  ...  -0.2531
#
#        exp_rank_binary  mut_rep_rank_netstabpan  foginess_score  \
# 0             1.000000                 0.700000             1.0
# 1             1.000000                 6.000000             1.0
# 2             1.000000                 0.030000             1.0
# 3             1.000000                 0.010000             1.0
# 4             1.000000                 0.030000             1.0
# ...                ...                      ...             ...
# 16155         0.000000                21.735778             1.0
# 16156         0.000000                21.735778             1.0
# 16157         0.322666                21.735778             1.0
# 16158         0.322666                21.735778             1.0
# 16159         0.000000                21.735778             1.0
#
#        HLA_expression      CD8A       CYT  response  prediction_rf  \
# 0          545.857673  1.505136  0.865589         1       0.171032
# 1          197.939610  1.505136  0.865589         0       0.105473
# 2          545.857673  1.505136  0.865589         1       0.177596
# 3          545.857673  1.505136  0.865589         1       0.202197
# 4          221.851612  2.858854  4.878506         1       0.349484
# ...               ...       ...       ...       ...            ...
# 16155      170.282114  0.831648  1.049071         0       0.125405
# 16156      170.282114  0.831648  1.049071         0       0.119713
# 16157      170.282114  0.831648  1.049071         0       0.138671
# 16158      129.406544  0.831648  1.049071         0       0.141692
# 16159      170.282114  0.831648  1.049071         0       0.145597
#
#        prediction_mlp
# 0            0.170139
# 1            0.101930
# 2            0.197839
# 3            0.153721
# 4            0.317432
# ...               ...
# 16155        0.115660
# 16156        0.084141
# 16157        0.152570
# 16158        0.101402
# 16159        0.354685
#
# [16160 rows x 54 columns]
# RF AUC: 0.6336
# MLP AUC: 0.5671

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(pred_df.response, pred_df.prediction_rf>0.3)
# Out:
# array([[14889,   897],
#        [  305,    69]])

# %%
plt.hist(pred_df.prediction_rf, alpha=0.5, label='prediction')
plt.hist(pred_df.response, alpha=0.5, label='response')
plt.legend()
plt.title("Histogram of the responses and the predicted probabilities\n Ranfom Forest")
plt.show()

plt.hist(pred_df.prediction_mlp, alpha=0.5, label='prediction')
plt.hist(pred_df.response, alpha=0.5, label='response')
plt.legend()
plt.title("Histogram of the responses and the predicted probabilities\n MLP")
plt.show()

# %%
fpr_rf, tpr_rf, threshold_rf = roc_curve(pred_df.response, pred_df.prediction_rf)
roc_auc_rf = auc(fpr_rf, tpr_rf)

fpr_mlp, tpr_mlp, threshold_mlp = roc_curve(pred_df.response, pred_df.prediction_mlp)
roc_auc_mlp = auc(fpr_mlp, tpr_mlp)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr_rf, tpr_rf, 'b', label = 'AUC RF= %0.2f' % roc_auc_rf)
plt.plot(fpr_mlp, tpr_mlp, 'g', label = 'AUC MLP= %0.2f' % roc_auc_mlp)

plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
# print prediction results 
print(pred_df.tail())
# print to outfile 
pred_df.to_csv(r'../../results/RandomForrest/tabels/pred_df_'+TME_inc+'.txt', index=None, sep=' ', mode='w')
# Out:
#               mw       aro        inst     helix      turn     sheet  cys_red  \
# 16155  1143.2740  0.000000   -8.960000  0.200000  0.300000  0.200000        0
# 16156  1200.2989  0.000000   41.600000  0.300000  0.100000  0.500000        0
# 16157  1072.1697  0.000000   45.111111  0.333333  0.111111  0.555556        0
# 16158  1072.1697  0.000000   45.111111  0.333333  0.111111  0.555556        0
# 16159  1341.5111  0.181818  128.363636  0.363636  0.090909  0.181818     1490
#
#        Mut_MHCrank_EL  Mut_MHCrank_BA  Allele_Frequency  ...      DAI  \
# 16155          0.7620          1.1224             0.018  ...   0.1978
# 16156          1.2147          3.8764             0.018  ...  12.3599
# 16157          0.1877          1.0638             0.018  ...   2.0491
# 16158          0.2198          0.6685             0.018  ...   4.5807
# 16159          1.4566          0.2730             0.020  ...  -0.2531
#
#        exp_rank_binary  mut_rep_rank_netstabpan  foginess_score  \
# 16155         0.000000                21.735778             1.0
# 16156         0.000000                21.735778             1.0
# 16157         0.322666                21.735778             1.0
# 16158         0.322666                21.735778             1.0
# 16159         0.000000                21.735778             1.0
#
#        HLA_expression      CD8A       CYT  response  prediction_rf  \
# 16155      170.282114  0.831648  1.049071         0       0.125405
# 16156      170.282114  0.831648  1.049071         0       0.119713
# 16157      170.282114  0.831648  1.049071         0       0.138671
# 16158      129.406544  0.831648  1.049071         0       0.141692
# 16159      170.282114  0.831648  1.049071         0       0.145597
#
#        prediction_mlp
# 16155        0.115660
# 16156        0.084141
# 16157        0.152570
# 16158        0.101402
# 16159        0.354685
#
# [5 rows x 54 columns]

# %%
# if you would like to run with a specefic model output
#model_out_dir="../../models/TME_included_2021-05-21_10-37-36"

rf_models = [filename for filename in os.listdir(model_out_dir) if filename.startswith("rf")]

# %%
# valid data 
num=0
# get vil set 
Valid = pd.read_csv('../../data/03_partitioning_data/validation/validation.txt', sep='\t')
Valid = Valid.dropna()

X_valid = Valid.drop(cols_to_drop, axis=1).reset_index(drop=True)
y_valid = Valid["response"]
pred_valid_rf = 0
#my_auc_valid=list()
for model in rf_models: 
    num += 1
    rf_model = pickle.load(open(model_out_dir +"/"+ model,"rb"))
    predictions_rf_valid = rf_model.predict_proba(X_valid)
    pred_valid_rf += predictions_rf_valid
    
    
pred_valid_rf = pred_valid_rf/num   
pred_df_valid = pd.DataFrame()
pred_df_valid = pred_df_valid.append(pd.concat([pd.DataFrame(X_valid, columns=X_valid.columns), 
                                        pd.Series(y_valid, name='response'), 
                                        pd.Series(pred_valid_rf[:,1], name='prediction_rf')], axis=1)).reset_index(drop=True)
                        
pred_df_valid = pred_df_valid.dropna()
print("RF AUC:",round(roc_auc_score(pred_df_valid.response, pred_df_valid.prediction_rf),4))
# print("MLP AUC:",round(roc_auc_score(pred_df_valid.response, pred_df_valid.prediction_mlp),4))
#my_auc_valid.append(round(roc_auc_score(pred_df_valid.response, pred_df_valid.prediction_rf),4))
# Out:
# RF AUC: 0.6437

# %%
pred_df_valid['response'].value_counts()
print(pred_df_valid['response'].value_counts())
# Out:
# 0    3246
# 1     141
# Name: response, dtype: int64

# %%
pred_df_valid['response'].value_counts()
# print prediction results 
pred_df_valid.to_csv(r'../../results/RandomForrest/tabels/pred_df_valid_'+TME_inc+'.txt', header=True, index=None, sep=' ', mode='w')

# %%
confusion_matrix(pred_df_valid.response, pred_df_valid.prediction_rf>0.3)
# Out:
# array([[3089,  157],
#        [ 120,   21]])

# %%
fpr_rf, tpr_rf, threshold_rf = roc_curve(pred_df_valid.response, pred_df_valid.prediction_rf)

# %%
fpr_rf, tpr_rf, threshold_rf = roc_curve(pred_df_valid.response, pred_df_valid.prediction_rf)
roc_auc_rf = auc(fpr_rf, tpr_rf)

#fpr_mlp, tpr_mlp, threshold_mlp = roc_curve(pred_df_valid.response, pred_df_valid.prediction_mlp)
#roc_auc_mlp = auc(fpr_mlp, tpr_mlp)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr_rf, tpr_rf, 'b', label = 'AUC RF= %0.2f' % roc_auc_rf)
#plt.plot(fpr_mlp, tpr_mlp, 'g', label = 'AUC MLP= %0.2f' % roc_auc_mlp)

plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
# CODE STOPS HERE !!!!!

# %%
pred_df = pd.DataFrame()
for file in files:
    
    print("Partition:", file)
    filename = file[1:]
#  train
    train = pd.read_csv(Inputdir + "/"+ file, sep=' ', header=0,  names=names)
    print(train.columns)
    for col in train.columns:
        print(col)
        train = train[col]
        train = train.dropna()
        train['response'].value_counts()
# Out:
# Partition: f002
# Index(['Mut_peptide', 'HLA_allele', 'cellular_prevalence', 'Expression_Level',
#        'priority_Score', 'Allele_Frequency', 'Mut_MHCrank_EL',
#        'Mut_MHCrank_BA', 'variant_allele_frequency', 'response',
#        'Self_Similarity', 'exp_rank_binary', 'clonal_mut', 'hydro', 'pI',
#        'Cancer_Driver_Gene', 'Misense_mutation', 'Frameshift_mutation',
#        'Inframe_deletion_mutation', 'Inframe_insertion', 'foginess_score',
#        'est_freq', 'mut_rep_rank_netstabpan', 'mw', 'aro', 'inst', 'grav',
#        'isopoint', 'helix', 'turn', 'sheet', 'cys_red', 'cys_cys_bond',
#        'X.Rank_PRIME', 'HLA_expression', 'CYT', 'CD8A'],
#       dtype='object')
# Mut_peptide
# HLA_allele
# cellular_prevalence
# Expression_Level
# priority_Score
# Allele_Frequency
# Mut_MHCrank_EL
# Mut_MHCrank_BA
# variant_allele_frequency
# response
# Self_Similarity
# exp_rank_binary
# clonal_mut
# hydro
# pI
# Cancer_Driver_Gene
# Misense_mutation
# Frameshift_mutation
# Inframe_deletion_mutation
# Inframe_insertion
# foginess_score
# est_freq
# mut_rep_rank_netstabpan
# mw
# aro
# inst
# grav
# isopoint
# helix
# turn
# sheet
# cys_red
# cys_cys_bond
# X.Rank_PRIME
# HLA_expression
# CYT
# CD8A
# Partition: f003
# Index(['Mut_peptide', 'HLA_allele', 'cellular_prevalence', 'Expression_Level',
#        'priority_Score', 'Allele_Frequency', 'Mut_MHCrank_EL',
#        'Mut_MHCrank_BA', 'variant_allele_frequency', 'response',
#        'Self_Similarity', 'exp_rank_binary', 'clonal_mut', 'hydro', 'pI',
#        'Cancer_Driver_Gene', 'Misense_mutation', 'Frameshift_mutation',
#        'Inframe_deletion_mutation', 'Inframe_insertion', 'foginess_score',
#        'est_freq', 'mut_rep_rank_netstabpan', 'mw', 'aro', 'inst', 'grav',
#        'isopoint', 'helix', 'turn', 'sheet', 'cys_red', 'cys_cys_bond',
#        'X.Rank_PRIME', 'HLA_expression', 'CYT', 'CD8A'],
#       dtype='object')
# Mut_peptide
# HLA_allele
# cellular_prevalence
# Expression_Level
# priority_Score
# Allele_Frequency
# Mut_MHCrank_EL
# Mut_MHCrank_BA
# variant_allele_frequency
# response
# Self_Similarity
# exp_rank_binary
# clonal_mut
# hydro
# pI
# Cancer_Driver_Gene
# Misense_mutation
# Frameshift_mutation
# Inframe_deletion_mutation
# Inframe_insertion
# foginess_score
# est_freq
# mut_rep_rank_netstabpan
# mw
# aro
# inst
# grav
# isopoint
# helix
# turn
# sheet
# cys_red
# cys_cys_bond
# X.Rank_PRIME
# HLA_expression
# CYT
# CD8A
# Partition: f001
# Index(['Mut_peptide', 'HLA_allele', 'cellular_prevalence', 'Expression_Level',
#        'priority_Score', 'Allele_Frequency', 'Mut_MHCrank_EL',
#        'Mut_MHCrank_BA', 'variant_allele_frequency', 'response',
#        'Self_Similarity', 'exp_rank_binary', 'clonal_mut', 'hydro', 'pI',
#        'Cancer_Driver_Gene', 'Misense_mutation', 'Frameshift_mutation',
#        'Inframe_deletion_mutation', 'Inframe_insertion', 'foginess_score',
#        'est_freq', 'mut_rep_rank_netstabpan', 'mw', 'aro', 'inst', 'grav',
#        'isopoint', 'helix', 'turn', 'sheet', 'cys_red', 'cys_cys_bond',
#        'X.Rank_PRIME', 'HLA_expression', 'CYT', 'CD8A'],
#       dtype='object')
# Mut_peptide
# HLA_allele
# cellular_prevalence
# Expression_Level
# priority_Score
# Allele_Frequency
# Mut_MHCrank_EL
# Mut_MHCrank_BA
# variant_allele_frequency
# response
# Self_Similarity
# exp_rank_binary
# clonal_mut
# hydro
# pI
# Cancer_Driver_Gene
# Misense_mutation
# Frameshift_mutation
# Inframe_deletion_mutation
# Inframe_insertion
# foginess_score
# est_freq
# mut_rep_rank_netstabpan
# mw
# aro
# inst
# grav
# isopoint
# helix
# turn
# sheet
# cys_red
# cys_cys_bond
# X.Rank_PRIME
# HLA_expression
# CYT
# CD8A

# %%
        
  #  if type(train["Self_Similarity"][0])==str:
  #      train = train[~train["Self_Similarity"].str.contains('acid')].reset_index(drop="True")
  #      train["Self_Similarity"] = train["Self_Similarity"].astype('float32')
        
        
    # test set 
        av_pred_rf = 0
        av_pred_mlp = 0

        test = pd.read_csv(Inputdir + '/c' + filename, sep=' ', header=0,  names=names)
        test = test.dropna()
        test['response'].value_counts()
        print(len(test))
       # test_pos = test[test.response==1]
        #  len(test_pos)
       # test_neg = test[test.response==0].sample(n=500, random_state=45)
       # test = shuffle(pd.concat([test_pos, test_neg], axis=0)).reset_index(drop=True)

            #Drop Self_similarity=='acid'
     #   if type(test["Self_Similarity"][0])==str:
     #       test = test[~test["Self_Similarity"].str.contains('acid')].reset_index(drop="True")
     #       test["Self_Similarity"] = test["Self_Similarity"].astype('float32')    

        # Because of downsampling is needed, make the downsampling 10 times (or 3 if you just debug :) ) 
        for i in range(n_sample): 
            train_pos = train[train.response==1]
            train_neg = train[train.response==0].sample(n=250, random_state=i) #, random_state=45
            train = shuffle(pd.concat([train_pos, train_neg], axis=0)).reset_index(drop=True)
            X_train = train.drop(cols_to_drop, axis=1).reset_index(drop=True)
            y_train = train["response"]

            feature_list = list(X_train.columns)

            # Instantiate the RF and the MLP
            rf = RandomForestClassifier(n_estimators = 1000, random_state = 42)
            mlp = MLPClassifier(max_iter=500, hidden_layer_sizes=200)

            # Train the models on training data
            rf.fit(X_train, y_train)
            mlp.fit(X_train, y_train)
            filename = model_out_dir +"/rf_"+file+"_"+"sample"+str(i)+".sav"
            pickle.dump(rf,open(filename,"wb"))
         #   pickle.dump(mlp,open("../../models/Version1/mlp_"+file+"sample"+str(i)),"wb")

            #Get fetures importance per partition
            importances = list(rf.feature_importances_)
            feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
            # Sort
            feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
            [print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances]
            # gather all feature importance 
            for pair in feature_importances:
                outfile.write(str(pair[0]) + "\t" + str(pair[1]) + "\n")



            # Test set 
            test.columns = train.columns 
            X_test = test.drop(cols_to_drop, axis=1).reset_index(drop=True)
            y_test = test["response"]  
            test_cols = X_test.columns

        # Plot the importances 
        #     plt.style.use('fivethirtyeight')
        #     x_values = list(range(len(importances)))
        #     plt.bar(x_values, importances, orientation = 'vertical')
        #     plt.xticks(x_values, feature_list, rotation='vertical')
        #     plt.ylabel('Importance'); plt.xlabel('Variable'); plt.title('Variable Importances')
        #     plt.show()

        # Predict values 

            predictions_rf = rf.predict_proba(X_test)
            predictions_mlp = mlp.predict_proba(X_test)

            av_pred_rf += predictions_rf
            av_pred_mlp += predictions_mlp

        pred_val_rf = av_pred_rf/n_sample
        pred_val_mlp = av_pred_mlp/n_sample

        pred_df = pred_df.append(pd.concat([pd.DataFrame(X_test, columns=X_test.columns), 
        pd.Series(y_test, name='response'), 
        pd.Series(pred_val_rf[:,1], name='prediction_rf'),                          
        pd.Series(pred_val_mlp[:,1], name='prediction_mlp')], axis=1)).reset_index(drop=True)

pred_df=pred_df.dropna()
print(pred_df)
# Print final AUCs 
print("RF AUC:",round(roc_auc_score(pred_df.response, pred_df.prediction_rf),4))
print("MLP AUC:",round(roc_auc_score(pred_df.response, pred_df.prediction_mlp),4))
    
            
        
outfile.close()

# %%
# valid data RCC

my_auc_valid=list()
for i in range(40,400,40): 
    Valid = pd.read_csv('../../data/Valdation/RCC_peptide_scrrened.txt', sep='\t')

    if type(Valid["Self_Similarity"][0])==str:
            Valid = Valid[~Valid["Self_Similarity"].str.contains('acid')].reset_index(drop="True")
            Valid["Self_Similarity"] = Valid["Self_Similarity"].astype('float32')
    print(i)
    Valid = Valid.dropna()
    Valid_pos = Valid[Valid.response==1]
    print(len(Valid))
    Valid_neg = Valid[Valid.response==0].sample(n=i, random_state=45)
    Valid = shuffle(pd.concat([Valid_pos, Valid_neg], axis=0)).reset_index(drop=True)
    X_valid = Valid.drop(['Mut_peptide', 'HLA_allele','response','Est..frequency','Allele_Frequency'], axis=1).reset_index(drop=True)
    y_valid = Valid["response"]
    predictions_rf_valid = rf.predict_proba(X_valid)
    predictions_mlp_valid = mlp.predict_proba(X_valid)
    
    pred_df_valid = pd.DataFrame()
    pred_df_valid = pred_df_valid.append(pd.concat([pd.DataFrame(X_valid, columns=X_valid.columns), 
                                            pd.Series(y_valid, name='response'), 
                                            pd.Series(predictions_rf_valid[:,1], name='prediction_rf'),
                                            pd.Series(predictions_mlp_valid[:,1], name='prediction_mlp')], axis=1)).reset_index(drop=True)
 
    print("RF AUC:",round(roc_auc_score(pred_df_valid.response, pred_df_valid.prediction_rf),4))
    print("MLP AUC:",round(roc_auc_score(pred_df_valid.response, pred_df_valid.prediction_mlp),4))
    my_auc_valid.append(round(roc_auc_score(pred_df_valid.response, pred_df_valid.prediction_rf),4))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-58-0efb903be0bc> in <module>
#       3 my_auc_valid=list()
#       4 for i in range(40,400,40):
# ----> 5     Valid = pd.read_csv('../../data/Valdation/RCC_peptide_scrrened.txt', sep='\t')
#       6
#       7     if type(Valid["Self_Similarity"][0])==str:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File ../../data/Valdation/RCC_peptide_scrrened.txt does not exist: '../../data/Valdation/RCC_peptide_scrrened.txt'
